# %%
import json

# %%
with open("return.json", "r", encoding="utf-8") as f:
    data = json.load(f)

# %%
data
# Out:
# {'document': 'files/9lk6gkjdg1ft',
#  'tree': [{'id': 'step-1',
#    'title': 'Central Axle',
#    'description': 'Rod and collar assembly for internal fuselage mechanism',
#    'dependencies': [],
#    'children': []},
#   {'id': 'step-2',
#    'title': 'Battery Box Base',
#    'description': 'Lower section of the battery/electronics housing',
#    'dependencies': [],
#    'children': []},
#   {'id': 'step-3',
#    'title': 'Housing Top',
#    'description': 'Upper section of the internal housing',
#    'dependencies': [],
#    'children': []},
#   {'id': 'step-4',
#    'title': 'Housing Assembly',
#    'description': 'Attaching brackets to the housing from Step 3',
#    'dependencies': ['step-3'],
#    'children': []},
#   {'id': 'step-5',
#    'title': 'Internal Mechanism',
#    'description': 'Installing the axle and lever mechanism into the housing',
#    'dependencies': ['step-1', 'step-2', 'step-4'],
#    'children': []},
#   {'id': 'step-6',
# ...
